# %%
# ============================================================
# 🧭 MarketMind — Static Visualization Dashboard
# ============================================================
# This notebook combines all Use Case outputs as image panels
# to present the analytical insights in one unified dashboard.

from IPython.display import Image, display, Markdown

display(Markdown("## 📊 MarketMind Project — Unified Dashboard (Static View)"))
display(Markdown("This dashboard combines insights from all 5 use cases."))

# ---------- Display Each Use Case ----------
sections = {
    "🧠 Use Case 1 — Product Launch Demand Forecasting": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase1_demand_forecast.png",
    "Use Case 1 - Trend Analysis": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase1_trend.png",
    "💼 Use Case 2 — Quarterly Earnings Prediction": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase2_quarterly_earnings_forecast.png",
    "💼 Use Case 2 — Correlation Market Sentiment": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase2_correlation_market_sentiment_and_stockprice.png",
    "⚠️ Use Case 3 — Crisis Response & Risk Forecasting": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase3_crisis_alert.png",
    "⚠️ Use Case 3 — Crisis Impact on Sales Volume": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase3_crisis_impact_on_sales_volume.png",
    "🏁 Use Case 4 — Competitive Intelligence Forecasting": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase4_average_market_sentiment.png",
    "🍂 Use Case 5 — Seasonal Demand Prediction": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase5_seasonal_demand_prediction.png",
    "🍂 Use Case 5 — Seasonal Sales Across Companies": "/Workspace/Users/abhishekgantana1@gmail.com/marketmind/Files/marketmind_project/visuals_and_dashboard/usecase5_seasonal_sales_across_companies.png"
}

for title, path in sections.items():
    display(Markdown(f"### {title}"))
    display(Image(filename=path, width=850))
    display(Markdown("---"))
# Out:
# ## 📊 MarketMind Project — Unified Dashboard (Static View)
# This dashboard combines insights from all 5 use cases.
# ### 🧠 Use Case 1 — Product Launch Demand Forecasting
# ---
# ### Use Case 1 - Trend Analysis
# ---
# ### 💼 Use Case 2 — Quarterly Earnings Prediction
# ---
# ### 💼 Use Case 2 — Correlation Market Sentiment
# ---
# ### ⚠️ Use Case 3 — Crisis Response & Risk Forecasting
# ---
# ### ⚠️ Use Case 3 — Crisis Impact on Sales Volume
# ---
# ### 🏁 Use Case 4 — Competitive Intelligence Forecasting
# ---
# ### 🍂 Use Case 5 — Seasonal Demand Prediction
# ---
# ### 🍂 Use Case 5 — Seasonal Sales Across Companies
# ---
